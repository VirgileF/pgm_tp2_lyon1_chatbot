# %% [markdown]
# # Master Data Science, Lyon 1
# # TP2 PGM (durée 6h)
#
# Alex Aussem (alexandre.aussem@univ-lyon1.fr)
#
# ***
#
# ## Chatbot with a sequence to sequence network and attention
# *************************************************************
#
# In this tutrial, you will learn how to teach a recurrent neural network to anwers various questions about the admission to the master in Data Science of Lyon 1 to varying degrees of success...
#
# From Siri to Google Translate, deep neural networks have enabled breakthroughs in machine understanding of natural language. Most of these models treat language as a flat sequence of words or characters, and use a kind of model called a recurrent neural network (RNN) to process this sequence
#
# The code was adapated by Alex Aussem from the Pytorch example "Translation with a Sequence to Sequence Network and Attention". **Author**: `Sean Robertson <https://github.com/spro/practical-pytorch>`
#
# Sentences are in French. Example: [> input, = target, < output]
#
#
#     > pourriez vous me renseigner ?
#     = oui volontiers d ou venez vous ?
#     < oui volontiers <EOS>
#
#     > quel est le corps professoral ?
#     = il est compose de chercheurs du liris
#     < il est compose de chercheurs du liris  <EOS>
#
# To deal with these types of variable-length input and output, we need to use a recurrent neural network (RNN). Feed-forward neural networks, such as convolutional neural networks, do not maintain internal state other than the network’s own parameters. An RNN maintains its internal state while reading a sequence of inputs, which in our case will be a sequence of words, thereby being able to process an input of any length.
#
# This is made possible by the simple but powerful idea of the `sequence
# to sequence network <http://arxiv.org/abs/1409.3215>`, in which two
# recurrent neural networks work together to transform one sequence to
# another. An encoder network condenses an input sequence into a vector,
# and a decoder network unfolds that vector into a new sequence.
#
# To improve upon this model we'll use an **attention mechanism**, which lets the decoder
# learn to focus over a specific range of the input sequence. The approach of incorporating attention mechanism has become one of the hottest topics in deep learning recently (<https://arxiv.org/abs/1507.01053>, <https://arxiv.org/abs/1409.0473>`).
#
#
# **Recommended Reading:**
#
# -  http://pytorch.org/ For installation instructions
# -  doc:`/beginner/deep_learning_60min_blitz` to get started with PyTorch in general
# -  doc:`/beginner/pytorch_with_examples` for a wide and deep overview
#
#
# It would also be useful to know about Sequence to Sequence networks and
# how they work:
#
# -  'Recursive Neural Networks with PyTorch with a recurrent tracker and TreeLSTM nodes
#     <https://devblogs.nvidia.com/parallelforall/recursive-neural-networks-pytorch>`
# -  `Learning Phrase Representations using RNN Encoder-Decoder for
#    Statistical Machine Translation <http://arxiv.org/abs/1406.1078>`
# -  `Sequence to Sequence Learning with Neural
#    Networks <http://arxiv.org/abs/1409.3215>`
# -  `Neural Machine Translation by Jointly Learning to Align and
#    Translate <https://arxiv.org/abs/1409.0473>`
# -  `A Neural Conversational Model <http://arxiv.org/abs/1506.05869>`
# -  `Sequence to Sequence Learning with Neural
#    Networks <http://arxiv.org/abs/1409.3215>`
# -  `Neural Machine Translation by Jointly Learning to Align and
#    Translate <https://arxiv.org/abs/1409.0473>`
# -  `A Neural Conversational Model <http://arxiv.org/abs/1506.05869>`

# %%
from __future__ import unicode_literals, print_function, division
from io import open
import unicodedata
import string
import re
import random
import numpy as np

import torch
import torch.nn as nn
from torch.autograd import Variable
from torch import optim
import torch.nn.functional as F

# %%
# %matplotlib inline

# %%
import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# Loading data files
# ==================
#
# The data for this project is a set of questions/anwers pairs.

# %% [markdown]
# We will be representing each word in a language as a one-hot
# vector, or giant vector of zeros except for a single one (at the index
# of the word). Compared to the dozens of characters that might exist in a
# language, there are many many more words, so the encoding vector is much
# larger. We will however cheat a bit and trim the data to only use a few
# hundred words per language.

# %% [markdown]
# We'll need a unique index per word to use as the inputs and targets of
# the networks later. To keep track of all this we will use a helper class
# called ``Lang`` which has word → index (``word2index``) and index → word
# (``index2word``) dictionaries, as well as a count of each word
# ``word2count`` to use to later replace rare words.

# %%
SOS_token = 0
EOS_token = 1

class Lang:
    def __init__(self, name):
        self.name = name
        self.word2index = {}
        self.word2count = {}
        self.index2word = {0: "SOS", 1: "EOS"}
        self.n_words = 2  # Count SOS and EOS

    def addSentence(self, sentence):
        for word in sentence.split():
            if word == '':
                print('****************',sentence)
            self.addWord(word)
         
    def addWord(self, word):
        if word not in self.word2index:
            self.word2index[word] = self.n_words
            self.word2count[word] = 1
            self.index2word[self.n_words] = word
            self.n_words += 1
        else:
            self.word2count[word] += 1

# %% [markdown]
# The files are all in Unicode, to simplify we will turn Unicode
# characters to ASCII, make everything lowercase, and trim most
# punctuation.

# %%
# Turn a Unicode string to plain ASCII, thanks to
# http://stackoverflow.com/a/518232/2809427
def unicodeToAscii(s):
    return ''.join(
        c for c in unicodedata.normalize('NFD', s)
        if unicodedata.category(c) != 'Mn'
    )

# Lowercase, trim, and remove non-letter characters except digits
def normalizeString(s):
    s = unicodeToAscii(s.lower().strip())
    #s = re.sub(r"([.!?])", r" \1", s)
    #s = re.sub(r"[^a-zA-Z.!?]+", r" ", s)
    #s = re.sub(r"[^a-zA-Z0-9?]+", r" ", s)
    #s = re.sub(r"[^a-zA-Z0-9?&\'\’\%\-]+", r" ", s)
    s = re.sub(r"[^a-zA-Z0-9?&\%\-]+", r" ", s)
    return s

# %%
s="Il eût été bien de s'inscrire en 2017 !! N'est-ce pas ?"
s = normalizeString(s)
print(s)
# Out:
# il eut ete bien de s inscrire en 2017 n est-ce pas ?

# %% [markdown]
# To read the data file we will split the file into lines, and then split
# lines into pairs. If we want to infer the question from the answers, the ``reverse``
# flag is added to reverse the pairs.

# %%
def readLangs(questions, answers, reverse=False):
    print("Reading lines...")
        
    lines = open('data/chatbot-M2-DS.txt', encoding='utf-8').\
        read().strip().split('\n')
    # Split every line into pairs and normalize
    pairs = [[normalizeString(s) for s in l.split('\t')] for l in lines]

    # Reverse pairs, make Lang instances
    if reverse:
        pairs = [list(reversed(p)) for p in pairs]
        input_lang = Lang(answers)
        output_lang = Lang(questions)
    else:
        input_lang = Lang(questions)
        output_lang = Lang(answers)

    return input_lang, output_lang, pairs

# %% [markdown]
# Here we set a limit to the length of input words (that includes ending punctuation + EOS token). The maximum input sentence length has to be determined in advance in order to parametrize the attention mechanism.

# %%
MAX_LENGTH = 15

#stopwords = 'de du des d le la les l ce c ci ça m me ma si t sur n en s si a y au un une on il nous vous je j'.split()

stopwords = []

def TrimWordsSentence(sentence):
    resultwords = [word for word in sentence.split() if word.lower() not in stopwords]
    resultwords = ' '.join(resultwords)
    return resultwords

def TrimWords(pairs):
    for pair in pairs: 
        pair[0] = TrimWordsSentence(pair[0])
        #pair[1] = pair[1].strip()
    return pairs

def filterPair(p):
    return len(p[0].split()) < MAX_LENGTH and \
        len(p[1].split()) < MAX_LENGTH 

def filterPairs(pairs):
    return [pair for pair in pairs if filterPair(pair)]

# %%
s="Il eût été bien de s'inscrire en 2017 !! N'est-ce pas ?"
print(s)
s = normalizeString(s)
print(s)
s = TrimWordsSentence(s)
print(s)
# Out:
# Il eût été bien de s'inscrire en 2017 !! N'est-ce pas ?
# il eut ete bien de s inscrire en 2017 n est-ce pas ?
# il eut ete bien de s inscrire en 2017 n est-ce pas ?

# %% [markdown]
# The full process for preparing the data is:
#
# -  Read text file and split into lines, split lines into pairs
# -  Normalize text, filter by length and content
# -  Make word lists from sentences in pairs

# %%
def prepareData(lang1, lang2, reverse=False):
    input_lang, output_lang, pairs = readLangs(lang1, lang2, reverse)
    print("Read %s sentence pairs" % len(pairs))
    pairs = TrimWords(pairs)
    
    for pair in [pair for pair in pairs if not filterPair(pair)]:
        print('%s (%d) -> %s (%d)' % (pair[0],len(pair[0].split()),pair[1],len(pair[1].split())))  
    
    pairs = filterPairs(pairs)
    
    print('')
    print("Trimmed to %s sentence pairs" % len(pairs))
    print("Counting words...")
    for pair in pairs:
        input_lang.addSentence(pair[0])
        output_lang.addSentence(pair[1])
        if '' in output_lang.word2index: print(pair[1].split())
    print("Counted words:")
    print(input_lang.name, input_lang.n_words)
    print(output_lang.name, output_lang.n_words)
    return input_lang, output_lang, pairs

# %%
input_lang, output_lang, pairs = prepareData('questions', 'answers', False)
print(random.choice(pairs))
#print(indexesFromSentence(input_lang,'bonjour'))
#print(input_lang.index2word[102], '->',input_lang.word2index['bonjour'])
# Out:
# Reading lines...
# Read 541 sentence pairs
# l y a plusieurs parcours ? (6) -> oui tout a fait deux parcours sont proposes pour le master data science le parcours mathematiques et le parcours informatique (20)
# quelles sont les mentions ? (5) -> deux parcours sont proposes pour le master data science le parcours mathematiques et le parcours informatique (16)
# il y a plusieurs parcours ? (6) -> oui tout a fait deux parcours sont proposes pour le master data science le parcours mathematiques et le parcours informatique (20)
# l faut obligatoirement avoir fait de l informatique pour candidater ? (11) -> non le master est ouvert aux etudiants d informatique de mathematiques et d un cursus ingenieur (16)
# il y a plusieurs parcours ? (6) -> oui tout a fait deux parcours sont proposes pour le master data science le parcours mathematiques et le parcours informatique (20)
# qui peut candidater ? (4) -> le master est ouvert aux etudiants titulaires d un master 1 en informatique mathematiques ou issus d un cursus ingenieur (20)
# faut-il faire un projet de fin d etude ? (9) -> oui il y a plusieurs projets a realiser et a presenter en fin d etudes (15)
# quand est-ce que le stage commence ? (7) -> le stage ne doit pas demarrer avant fin janvier et ne peut depasser le 30 septembre (16)
# il faut avoir un stage avant le debut des cours ? (11) -> non il n est pas necessaire de trouver un stage avant le debut des cours (15)
# il faut trouver un stage avant le debut des cours ? (11) -> non il n est pas necessaire de trouver un stage avant le debut des cours (15)
# on doit trouver un stage avant de commencer ? (9) -> non il n est pas necessaire de trouver un stage avant le debut des cours (15)
# il faut avoir un stage avant de commencer le master ? (11) -> non il n est pas necessaire d avoir un stage avant de commencer le master (15)
# on peut faire son stage a l etranger ? (9) -> oui vous pouvez faire votre stage ou vous le souhaitez sous reserve de validation par l universite (17)
# il faut connaitre le python ? (6) -> il n est pas necessaire de maitriser ce langage mais plus vous en savez mieux c est (17)
# il faut connaitre le r ? (6) -> il n est pas necessaire de maitriser ce langage mais plus vous en savez mieux c est (17)
# on doit apprendre le scala ? (6) -> il n est pas necessaire de maitriser ce langage mais plus vous en savez mieux c est (17)
# c est obligatoire de connaitre le python ? (8) -> il n est pas necessaire de maitriser ce langage mais plus vous en savez mieux c est (17)
# est ce que l universite nous aide pour trouver des stages ? (12) -> oui les etudiants sont informes des forums organises par l universite et les proffesseurs relayent beaucoups d offres (18)
# quels sont les theses proposees pour la rentree 2019 ? (10) -> l apprentissage de la structure des reseaux bayesiens avec des applications sur des donnees medicales (15)
# comment l etudiant est note ? (6) -> ca depend de chaque matiere en fonction de ses notes de tp cc et partiels (15)
# j ai besoin du planning de l annee courante ou passee merci de me l envoyer (16) -> vous trouverez le planning sur le site web du master (10)
# linux et python ? (4) -> une remise a niveau en linux et python est proposee et conseillee par l etablissement  (15)
# quel est le nombre de credits pour chaque matiere du master 2 data science ? (15) -> presques toutes les matieres valent 3 credits (7)
# quelles sont les matieres du master data science ? (9) -> graphes complexite combinatoire data visualization big data analytics cloud computing statistique inferentielle modeles de regression modeles graphiques probabilistes data mining machine learning fondamentaux mathematiques pour les data science  (28)
# quels sont les prerequis necessaire pour le master data science ? (11) -> il est conseille d avoir une bonne connaissance des mathematiques et statistique bases de donnees avancees analyse de donnees programmation en pyhton ou r  (24)
# combien de parcours sont proposes ? (6) -> deux parcours sont proposes pour le master data science le parcours mathematiques et le parcours informatique (16)
# des liens avec des institutions etrangeres ? (7) -> il y a des liens etroits avec des institutions reconnues au niveau national et international (15)
# est-ce que le master 2 data science est en partenariat avec une ou plusieurs ecoles ? (16) -> oui les etudiants de centrale lyon et de lyon1 assistent aux memes cours le long de cette formation (18)
# il y a t-il des travaux pratiques en m2 data science ? (12) -> oui et cela dans l objectif de maitriser des technologies et d acquerir des competences fortement demandees dans le marche de travail  (22)
# est-ce qu il y a un terrain de football ? (10) -> oui l universite claude bernard lyon 1 est dotee de plusieurs espaces vert terrains sportifs (15)
# est-ce que la formation propose des certifications gratuites ? (9) -> non pour le moment mais les professeurs exigent lors des tps de travailler avec des technologies qui sont fortement demandees dans le marche de travail (25)
# le diplome de master 2 data science informatique est-il different de celui du parcours mathematique ? (16) -> il n y a aucune difference entre les deux diplomes ainsi que ils ont les memes debouches (17)
# il y a-t-il un service qui fait la prospection des stages pour les etudiants ? (15) -> oui le service s appelle career center et le responsable vous transmets des offres de stages  (16)
# la formation comporte combien de modules ? (7) -> il y a 10 unite d enseignements pour le semestre 3 et 4 ue pour le s4 (17)
# quel est la salaire moyen d un datascientist ? (9) -> cela depend du niveau d exeprtise pour un profil junior le salaire varie entre 37 000 et 50 000 euros  (20)
# quelle est l expertise requise pour le stage ? (9) -> un profil junior nous interesse c est a dire a peu pres deux ans d experience  (16)
# quels sont les moyens pour vous contacter ? (8) -> vous pouvez les contacter en consultant le site web ou directement en contactant le support rh  (16)
# quel est le meilleur moyen pour developper ses competences en tant que datascientist ? (14) ->  participer a des projets et des competitions kaggle est un bon moyen pour developper ses competences  (16)
# faut il valider toutes les matieres pour valider le master parcours mathematiques ? (13) -> non du moment que la moyenne est au dessus de 10 pour les matieres et pour le stage  (18)
# quels sont les cours proposes dans le cadre de le master data science ? (14) -> ce master comprend des cours tels que machine learning pgm ou encore fondamentaux mathematiques pour la data science  (18)
# pensez-vous que le master intelligence artificielle m est plus adapte que le master data science ? (16) -> si vous avez un profil plutot mathematiques je vous conseille le master data science  (14)
# a-t-on besoin d avoir son propre ordinateur pour ce parcours ? (11) -> il n est pas indispensable d avoir son propre pc mais cela est fortement recommande  (15)
# on peut faire son stage au japon ? (8) -> oui vous pouvez faire votre stage ou vous le souhaitez sous reserve de validation par l universite (17)
# peut-on trouver a manger pres des cours ? (8) -> oui il y a une tres bonne cafeteria tenue par les eleves dans le batiment nautibus  (16)
#
# Trimmed to 497 sentence pairs
# Counting words...
# Counted words:
# questions 603
# answers 623
# ['quel est le salaire durant le stage ?', 'la paye minimale durant le stage est de 550 euros mensuels environ']

# %%
print(set(input_lang.word2index))
# Out:
# {'faut', 'soutien', 'commencer', 'pdf', 'proposez', 'obligatoirement', 'cordialement', 'sans', 'belle', 'marseille', 'parallele', 'necessaire', 'comme', 'aux', 'apprendre', 'obligatoire', 'specialisations', 'data', 'anglais', 'remuneration', 'double', 'pc', 'lettre', 'mieux', 'maximale', 'gratuitement', 'hui', 'chaque', 'de', 'cafe', 'dur', 'emploi', 'trouver', 'quelle', 'langue', 'des', 'temps', 'equipe', 'reims', 'mathematiques', 'necessaires?', 'rendus', 'un', 'particulier', 'travail', 'quelque', 'langages', 'ceremonie', 'pre-embauche', 'vacances', 'choisies', 'metiers', 'quand', 'deposer', 'merci', 'enseignees', 'dieu', 'integrervotre', 'd', 'deja', 'doit', 'moyenne', 'pour', 'sur', 'oblige', 'developper', 'remise', 'propos', 't-il', 'ton', 'valider', 'tous', 'campus', 'matieres', 'pfe', 'n', 'hesite', 'billard', 'robot', 'ne', 'continu', 'professeurs', 'vaut', 'corps', 'maquette', 'parler', 'prefere', 'bonnes', 'demarches', 'liens', 'differences', 'transversaux', 'chimie', 'souhaite', 'matiere', 'indecis', 'rendre', 'enseignes', 'possible', 'faut-il', 'forum', 'trouve', 'similaires', 'avoir', 'combien', '?', 'interesse', 'ont', 'est-il', 'domaine', 'autre', 'entres', 'tp', 'fais', 'prepare', 'data?', 'chose', 'est', 'renseignements', 'negocier', 'grenoble', 'monde', 'detaillee', 'informatique', 'chances', 'recruter', 'recent', 'ligne', 'jour', 'date', 'aider', 'possibles', 'bon', 'nom', 'sortie', 'annee', 'perspectives', 'sujets', 'pauses', 'rapport', 'toeic', 'peut-on', 'auriez-vous', 'suivent', 'monsieur', 'retirer', 'ville', 'sommes-nous', 'master?', 'j', 'samedis', 'professionnelle', 'dates', 'ma', 'choisir', 'personnel', 'il', 'gentil', 'coute', 'poursuite', 'questions', 'entreprise', 'qui', 'ue', 'ues', 'prerequis', 'programmation', 'et', 'bot', 'la', 'proposes', 'appelles', 'tout', 'horaires', 'insa', 'salut', 'villeubanne', 'forme', 'autres', 'artificielle', 'format', 'reseaux', 'metier', 'offres', 'professoral', 'effectif', 'gens', 'est-tu', 'sujet', 'ca', 'learning', 'venant', 'aurais', 'compensent-elles', 'propre', 'angers', 'dure', 'viennent', 'postuler', 'association', 'annees', 'avons-nous', 'envoyer', 'modes', 'qualite', 'eu', 'jeu', 'etranger', 'cools', 'recherche', '3', 'robotique', 'encourager', 'pourquoi', 'competences', 'etages', 'nous', 'createur', 'diplome', 'rappels', 'precisement', 'apres', 'doctorat', 'peux', 'math', 'python', 'evaluation', 'difference', 'contenu', 'detail', 'consiste', 'ce', 'est-ce', 'dataviz', 'compris', 'voudrais', 'uniquement', 'reponse', 'leur', 'poursuivre', 'candidater', 'suis', 'paye', 'reconnu', 'scolaire', 'quelques', 'suivi', 'restaurant', 't', 'salutations', 'science', 'controle', 'recevons', 'inscrire', 'necessaires', 'fait', 'cursus', 'promotion', 'etude', 'options', 'module', 'pas', 'langage', 'enseignants', 'qu', 'international', 'ou', 'stagiaire', 'risque', 'recommendation', 'table', 'professionnel', 't-on', 'gros', 'graphes', 'types', 'proposez-vous', 'etre', 'ete', 'secteur', 'aurais-je', 'quoi', 'durs', 'quel', 'salaire', 'effectuer', 'ia', 'doua', 'informations', 'these', 'propose', 'fenetre', 'pardon', 'annuel', 'stage', 'facilement', 'etudiante', 'soutenance', 'question', 'bio', 'dans', 'utiliser', 'utilises', 'pourriez-vous', 'ordinateurs', 'exploitation', 'urgent', 'taille', 'exploser', 'rattrapages', 'inscriptions', 'professeur', 'unites', 'perdu', 'pourcentage', 'deep', 'scolarite', 'pouvons', '2018', 'sous', 'an', 'physique', 'proposees', 'minimale', 'issu', 'inscription', 'mise', 'big', 'etudiant', 'sont-ils', 'durent', 'maths', 'responsable', 'sympa', 'aujourd', 'demandees', 'redoublants', 'atouts', 'lyon', 'du', 'oriente', 'pourrais-je', 'refaire', 'ai', 'appelle', 'a', 'ordinateur', 'cela', 'contacter', 'proposent', 'plus', 'nautibus', 'master', 'mining', 'concernent', 'etes-vous', 'deux', 'que', 'pre-requis', 'precedentes', 'adherer', 'attendre', 'vous', 'bien', 'meme', 'carte', 'dire', 'paris', 'situe', 'facile', 'votre', 'allez-vous', 'cout', 'c ...

# %%
print(set(output_lang.word2index))
# Out:
# {'faut', 'commencer', 'visiter', 'face', 'obligatoirement', 'cordialement', 'volontiers', 'linux', 'espece', 'radieux', 'necessaire', 'aux', 'aussem', 'mchine', 'obligatoire', 'prie', 'trouverez', 'specialisations', '15min', 'data', 'anglais', 'desirez', 'different', 'forte', 'mieux', 'maximale', 'hui', 'football', 'chaque', 'de', 'trouver', 'quelle', 'des', 'temps', 'parking', 'equipe', 'mathematiques', 'scala', 'un', 'travail', 'tps', 'langages', 'vacances', 'deposer', 'merci', '400', 'collaborations', 'd', 'six', 'devrez', 'doit', 'etroites', 'pour', 'sur', 'mini-projets', 'exige', 'choix', 'laisse', 'ces', 'remise', 'intervenants', 'difficultes', 'valider', 'permettent', 'soutenances', 'promotions', 'campus', 'suffisament', 'matieres', 'jours', 'n', 'b1', 'posez', 'robot', 'ne', 'probabilistes', 'vaut', 'envoyee', 'parler', 'former', 'apprecier', 'test', 'titulaires', 'rendre', 'finir', 'possible', 'preferable', 'forum', 'avoir', '16', 'vingt', '?', 'autorises', 'ont', '20', 'fur', 'domaine', 'aout', 'tp', 'ecrit', 'obligatoires', 'est', 'note', 'apprise', '000', 'decouvrir', 'appliquees', '50%', 'volontier', 'premier', 'regulier', 'monde', 'informatique', 'precarisation', 'devriez', 'experience', 'explosif', 'suivez', 'date', 'visualiser', 'veuillez', 'aider', 'alexandre', 'commence', 'meilleure', 'bon', 'socle', 'dix', 'annee', 'peuvent', 'garde', 'serieux', 'bonne', 'toeic', 'certains', 'salles', 'tant', 'monsieur', 'ville', 'web', 'devez', 'b2', 'j', 'scientist', 'professionnelle', 'referez', 'rentrer', 'il', 'polytech', 'pourrez', 'fevrier', 'coute', 'support', '30', 'poursuite', 'inference', 'font', 'ue', 'qui', 'questions', 'entreprise', 'tronc', 'prerequis', 'ayez', 'et', 'bot', 'la', 'proposes', 'indifferencie', 'tout', 'huit', 'toujours', 'developpement', 'entretien', 'possede', 'effectivement', 'compose', 'probleme', 'demande', 'cheque', 'sommes', 'reseaux', 'effectues', 'metier', 'r', 'offres', 'journee', 'accueil', 'navre', 'sujet', 'ca', 'learning', 'taux', 'lyonnais', 'doivent', 'essayer', 'tirez', 'planning', 'ferai', 'oui', 'postuler', 'soleil', 'association', 'egalement', 'pile', 'eu', 'important', 'recherche', '3', 'sitecontacts', 'etages', 'moins', 'service', 'nous', 'terminent', 'rappels', 'apres', 'math', 'postulez', 'elu', 'directement', 'python', '5', 'malheureusement', 'contenu', 'nombreux', 'cinq', 'ce', 'bien-sur', 'profil', 'leur', 'reponse', 'poursuivre', 'candidater', 'suis', 'charme', 'ses', 'cinquieme', 'paye', 'quelques', 'oublie', 'fois', 'science', 'mac', 'selon', 'inscrire', 'fait', 'pourriez', 'etude', 'options', 'pas', 'enseignants', 'seules', 'qu', 'sitn', 'ou', 'proximite', 'ouvre', 'sauf', 'professionnel', 'graphes', 'basketball', 'internet', 'etre', '2019', 'vos', 'mois', 'magistraux', 'secteur', 'quoi', 'ete', 'quel', 'effectuer', 'dizaine', 'doua', 'informations', 'these', 'propose', 'seule', 'pres', 'pardon', 'dossier', 'comptent', 'vers', 'systemes', 'stage', 'mensuels', 'septembre', 'etudiante', 'perfectionner', 'serez', 'question', 'tourne', 'suffisant', 'dans', 'juin', 'haytham', 'cifre', 'consulter', 'bancaire', 'ordinateurs', 'exploitation', 'taille', 'inscriptions', 'universitaires', 'bu', 'scolarite', '2018', 'pausent', 'passage', 'an', 'travailler', 'aider?', 'minimale', 'lyon1', 'recommande', 'inscription', 'sas', 'mise', 'big', 'durent', 'maths', 'pleine', 'aujourd', 'autour', 'turing', '12', 'du', 'lyon', 'oriente', 'obtenir', 'ecoute', 'jointe', 'payer', 'faite', 'mr', 'refaire', 'ai', 'pgm', 'devient', 'appelle', 'a', 'ouverte', 'cela', 'contacter', 'elghazel', 'proposent', 'plus', 'pratiquement', 'applicatif', 'nautibus', 'master', 'mining', 'graphiques', 'pourvu', 'concernent', 'deux', 'que', 'specifiquement', 'continus', 'nombreuses', 'redoublant', '6', 'informaticiens', 'vous', 'prends', 'chacun', 'restaurants', 'bien', 'meme', 'carte', 'lineaire', 'paris', 'situe', 'recevrez', 'nombre', 'rugby', 'fortement', 'tennis', 'votre', 'regression', 'nomchatbot', 'mesu ...

# %%
pairs
# Out:
# [['quels sont les parcours ?',
#   'le m2 ouvre en informatique et mathematiques appliquees'],
#  ['c est un m2 ou un m1 ?', 'c est un m2'],
#  ['quels mentions ?', 'mention informatique ou mathematiques'],
#  ['je souhaite m inscrire', 'les inscriptions 2018 se font sur ecandidat'],
#  ['je veux m inscrire', 'les inscriptions 2018 se font sur ecandidat'],
#  ['je souhaite postuler', 'les inscriptions 2018 se font sur ecandidat'],
#  ['je souhaite postuler au master en 2018',
#   'les inscriptions se font sur ecandidat'],
#  ['quels apprentissages ?',
#   'acquerir un socle de connaissances techniques en machine learning'],
#  ['quels cours ?',
#   'acquerir un socle de connaissances techniques en machine learning'],
#  ['les atouts de ce parcours ?',
#   'une pedagogie fondee sur de nombreuses etudes de cas'],
#  ['quels atouts ?', 'une pedagogie fondee sur des retours d experience'],
#  ['quelle pedagogie ?',
#   'une pedagogie fondee sur de nombreuses etudes de cas'],
#  ['quel est le corps professoral ?', 'il est compose de chercheurs du liris '],
#  ['quelles synergies ?',
#   'forte synergie entre milieu academique et monde professionnel'],
#  ['des liens avec le monde professionnel ?',
#   'forte synergie entre milieu academique et monde professionnel'],
#  ['dans quelle langue ?', 'en francais certains cours sont en anglais'],
#  ['doctorat ?', 'oui c est possible apres le master'],
#  ['these ?', 'oui c est possible apres le master'],
#  ['quelle date de rentree ?', 'la rentree est le 5 septembre'],
#  ['quand ?', 'c est le 5 septembre'],
#  ['la date de rentree ?', 'le 5 septembre'],
#  ['c est quand la rentree ?', 'le 5 septembre'],
#  ['combien de places ?', 'il y a 20 places en tout'],
#  ['quels sont les prerequis ?', 'les mathematiques et les statistiques'],
#  ['si je suis etranger ?', 'il y a 10 places pour les etudiants etrangers'],
#  ['si je viens de nantes ?', 'il y a 5 places'],
#  ['si je viens de lyon ?', 'il y a 20 places'],
#  ['si je viens de paris ?', 'il y a 5 places'],
#  ['si je viens de marseille ?', 'il y a 5 places'],
#  ['quelle date ?', 'c est le cinq septembre'],
#  ['quand ?', 'le cinq septembre'],
#  ['combien de places ?', 'il y a 20 places en tout'],
#  ['il faut des prerequis ?', 'en mathematiques et statistiques oui'],
#  ['comment faire si je suis etranger ?',
#   'il y a dix places aux etudiants hors ue'],
#  ['si je n ai pas fait mon m1 a lyon 1 ?',
#   '5 places pour ceux qui ont un m1 francais'],
#  ['si je viens de lyon ?', 'il y a vingt places pour les lyonnais'],
#  ['si je viens de paris ?',
#   'cinq places pour les titulaires d un master francais'],
#  ['si je viens de marseille ?', 'il y a 5 places'],
#  ['quelle date est la rentree ?', 'la rentree est le 5 septembre 2018'],
#  ['quand est-ce ?', 'le cinq septembre'],
#  ['combien de places ?', 'il y a 20 places en tout'],
#  ['y a-t-il des prerequis necessaires?',
#   'oui en mathematiques et statistiques'],
#  ['si je suis etranger ?', 'il y a 10 places pour les etudiants etrangers'],
#  ['si je viens de nantes ?',
#   'cinq places pour les titulaires d un master francais'],
#  ['si je viens de lyon ?', 'il y a 20 places'],
#  ['si je viens de pau ?',
#   'cinq places pour les titulaires d un master francais'],
#  ['si je viens de marseille ?', '5 places pour ceux qui ont un m1 francais'],
#  ['quelle date ?', 'le cinq septembre'],
#  ['c est quand la rentree ?', 'le 5 septembre'],
#  ['combien de places ?', 'il y a 20 places en tout'],
#  ['quels sont les connaissances demandees ?', 'mathematiques et statistiques'],
#  ['si je suis etranger ?', 'il y a 10 places pour les etudiants etrangers'],
#  ['si je viens de nantes ?',
#   '5 places pour les titulaires d un master francais'],
#  ['si je viens de lyon ?', 'il y a 20 places pour vous'],
#  ['si je viens de reims ?',
#   'cinq places pour les titulaires d un master francais'],
#  ['si je viens de marseille ?', '5 places pour ceux qui ont un m1 francais'],
#  ['a quelle date ?', 'le 5 septembre 2018'],
#  ['quand ?', 'c est le 5 septembre 2018'],
#  ['combien de places en tout ?', 'il y a 20 places en tout'],
#  ['quels prerequis ?', 'mathematiques et statistiques'],
#  ['et pour les etrangers ?', 'il y a 10 places pour les etudiants etrangers'],
#  ['si je viens de angers ?',
#   '5 places pour les titulaires d un master francais'],
#  ['si je viens de paris ?',
#   '5 places pour les titulaires d un master francais'],
#  ['si je viens de grenoble ?', '5 places pour ceux qui ont un m1 francais'],
#  ['le master forme a quel metier ?', 'au metier de data scientist'],
#  ['le master forme a quels metiers ?', 'au metier de data scientist'],
#  ['le master prepare a quel emploi ?', 'au metier de data scientist'],
#  ['le master prepare a quel metier ?', 'au metier de data scientist'],
#  ['quels sont les debouches ?', 'les data sciences'],
#  ['cela debouche sur quoi ?', 'au metier de data scientist'],
#  ['quel metier apres ?', 'le metier de data scientist'],
#  ['c est un formation de qualite', 'merci'],
#  ['c est un super master', 'merci'],
#  ['c est un master reconnu', 'oui il le devient'],
#  ['je suis interesse', 'merci j en prends note'],
#  ['j aimerais faire votre master', 'merci j en prends note'],
#  ['je veux faire ce master', 'merci j en prends note'],
#  ['votre master m interesse', 'merci j en prends note'],
#  ['cordialement', 'cordialement'],
#  ['salutations', 'cordialement'],
#  ['bonjour', 'bonjour'],
#  ['bonjour monsieur', 'bonjour'],
#  ['bonjour professeur', 'bonjour'],
#  ['merci monsieur', 'de rien'],
#  ['merci bien', 'de rien'],
#  ['merci de votre aide', 'de rien'],
#  ['merci pour les renseignements', 'de rien'],
#  ['c est gentil', 'merci'],
#  ['pourriez-vous me renseigner', 'oui volontiers quel est votre profil ?'],
#  ['j ai besoin d aide', 'oui volontiers quel est votre profil ?'],
#  ['j ai une question', 'oui posez votre question'],
#  ['j ai des questions', 'oui posez vos questions'],
#  ['c est possible de s inscrire ?', 'oui d ou venez vous ?'],
#  ['mes salutations', 'bonjour'],
#  ['il y a un stage a faire ?', 'oui de six mois a partir de mars'],
#  ['il faut faire un stage ?', 'oui de six mois a partir de mars'],
#  ['la duree du stage ?', 'six mois'],
#  ['le stage dure combien de temps ?', 'six mois'],
#  ['il faut etre titulaire d un master en informatique ?',
#   'oui c est preferable'],
#  ['j ai un master un en bio informatique',
#   'il faut refaire un master un en informatique'],
#  ['j ai un master un en mathematiques', 'il faut postuler au master ds math'],
#  ['j ai un master un en chimie',
#   'il faut refaire un master un en informatique'],
#  ['j ai fait master un en bio informatique',
#   'il faut refaire un master un en informatique'],
#  ['j ai fait master un en mathematiques',
#   'il faut postuler au master ds math'],
#  ['j ai un master un en physique',
#   'il faut refaire un master un en informatique'],
#  ['quel est le contenu de la formation ?',
#   'il faut regarder sur notre site web'],
#  ['quels sont les cours dispenses ?', 'il faut regarder sur notre site web'],
#  ['quels sont les cours donnes ?', 'il faut regarder sur notre site web'],
#  ['quels sont les cours enseignes ?', 'il faut regarder sur notre site web'],
#  ['quels sont les cours ?', 'il faut regarder sur notre site web'],
#  ['quelles sont les unites d enseignement ?',
#   'il faut regarder sur notre site web'],
#  ['il y a des cours de graphes ?', 'oui'],
#  ['il y a des cours de data visualization ?', 'oui'],
#  ['il y a des cours de big data ?', 'oui il y a un cours en big data'],
#  ['il y a des cours de python ?', 'oui il y a des tps de python'],
#  ['il y a des cours de data mining ?', 'oui il y a un cours de data mining'],
#  ['il y a des cours de graphes ?', 'oui il y a un cours de graphes'],
#  ['il y a des cours de machine learning ?',
#   'oui il y a 2 cours de machine learning'],
#  ['il y a des rappels de mathematiques ?',
#   'oui pour les etudiants de ds informatique'],
#  ['il y a des rappels d informatique ?', 'oui pour les etudiants de ds math'],
#  ['quels langages de programmation ?', 'python essentiellement'],
#  ['il y a des cours de graphes ?', 'oui'],
#  ['il y a de la data visualization ?', 'oui'],
#  ['il y a du big data ?', 'oui'],
#  ['il y a du python ?', 'oui'],
#  ['y a-t-il du data mining ?', 'oui'],
#  ['il y a des cours de graphes ?', 'oui'],
#  ['il y a des cours de machine learning ?',
#   'oui il y a 2 cours de machine learning'],
#  ['il y a des rappels de mathematiques ?',
#   'oui pour les etudiants de ds informatique'],
#  ['il y a des rappels d informatique ?', 'oui pour les etudiants de ds math'],
#  ['combien d ects par cours ?', 'trois ects'],
#  ['il y a combien de candidats ?',
#   'deux cents environs la selection est rude'],
#  ['il y a beaucoup de candidats chaque annee ?',
#   'deux cents environs la selection est rude'],
#  ['le niveau est-il eleve ?', 'le niveau est plutot bon oui '],
#  ['quel est le niveau ?', 'le niveau est plutot bon'],
#  ['les cours sont durs ?', 'non mais il faut travailler assidument'],
#  ['le master est-il difficile a suivre ?',
#   'non mais il faut travailler assidument'],
#  ['les cours-ils difficile a suivre ?',
#   'non mais il faut travailler assidument'],
#  ['vous pouvez m aider ?', 'oui je suis la pour vous renseigner'],
#  ['j ai besoin d aide', 'je suis la pour vous renseigner'],
#  ['j ai besoin d un renseignement', 'je suis la pour vous renseigner'],
#  ['j ai besoin de renseignements', 'je suis la pour vous renseigner'],
#  ['j ai des questions', 'je suis la pour vous aider'],
#  ['le master est-il ouvert en alternance ?', 'non'],
#  ['on peut le faire en alternance ?', 'non'],
#  ['on peut faire ce m2 en alternance ?', 'non'],
#  ['il est possible de faire ce m2 en alternance ?', 'non'],
#  ['comment faire pour s inscrire ?', 'il faut contacter la scolarite'],
#  ['et pour s inscrire je fais comment ?', 'il faut contacter la scolarite'],
#  ['est-il encore possible de s inscrire ?', 'il faut contacter la scolarite'],
#  ['je voudrais m inscrire', '', 'il faut contacter la scolarite'],
#  ['et pour les inscriptions on fait comment ?',
#   'il faut contacter la scolarite'],
#  ['est-il encore possible de s inscrire ?', 'il faut consulter le calendrier'],
#  ['puis-je encore m inscrire ?', 'il faut consulter le calendrier'],
#  ['je peux encore m inscrire ?', 'il faut consulter le calendrier'],
#  ['c est un master en 2 ans ?', 'non c est un m2 d un an '],
#  ['est-ce un master en deux ans ?', 'non c est un m2 d un an '],
#  ['le master dure 2 ans ?', 'non c est un m2 d un an '],
#  ['c est un master en 1 an ?', 'oui c est un m2 d un an '],
#  ['est-ce un master en un an ?', 'oui c est un m2 d un an '],
#  ['le master dure un an ?', 'oui c est un m2 d un an'],
#  ['y a t-il eu des redoublants les annees passees ?', 'non un seul'],
#  ['est-ce un master oriente recherche ou entreprise ?',
#   'il s agit d un m2 indifferencie'],
#  ['avez-vous une maquette detaillee de ce master ?',
#   'oui je vous l ai envoyee en piece jointe'],
#  ['ou puis-je trouver le detail des ues proposees ?',
#   'sur le site du master '],
#  ['est-ce un master pro ou recherche ?', 'il s agit d un m2 indifferencie'],
#  ['auriez-vous une maquette de ce master ?',
#   'oui je vous l ai envoyee en piece jointe'],
#  ['peut-on faire un stage en entreprise ?', 'oui'],
#  ['je viens de strasbourg', 'il y a cinq places disponibles dans ce master '],
#  ['aurais-je des vacances ?',
#   'les vacances ne doivent pas etre votre motivation '],
#  ['quel est la reputation du master ?',
#   'c est a vous de faire sa reputation '],
#  ['quel est le pourcentage d embauche en fin d etudes ?',
#   'en data sciences 100% '],
#  ['comment sont les enseignants ?', 'a vous de vous faire votre avis '],
#  ['je suis indecis', 'tirez a pile ou face '],
#  ['je suis indecise', 'tirez a pile ou face '],
#  ['quel est le temps a lyon ?', 'plutot bon '],
#  ['les gens sont-ils cools a lyon ?', 'a vous de vous faire votre avis '],
#  ['les gens sont-ils sympa a lyon ?', 'a vous de vous faire votre avis '],
#  ['j ai peur de ne pas reussir', 'c est toujours mieux que ne rien faire '],
#  ['j ai peur de rater', 'c est toujours mieux que ne rien faire '],
#  ['combien d etudiants ont rate l an dernier ?', 'un seul '],
#  ['j hesite avec le master intelligence artificielle',
#   'il faut effectivement faire un choix '],
#  ['peut-on suivre deux cursus en parallele',
#   'non sauf les etudiants de l ecl '],
#  ['j aime la data science', 'c est un bon point '],
#  ['je n aime pas la data science', 'que faites-vous sur ce forum ?'],
#  ['avons-nous cours les samedis ?',
#   'non mais vous pourrez travailler a la bu'],
#  ['avons-nous cours le week-end ?', 'non mais la bu est ouverte'],
#  ['puis-je avoir le contact d un ancien eleve ?', 'oui bien sur'],
#  ['peut-on faire le master en alternance ?', 'non'],
#  ['je n ai pas compris', 'j ai oublie votre question pardon'],
#  ['pardon ?', 'j ai oublie votre question pardon'],
#  ['qui sont les enseignants du master ?', 'des chercheurs du liris'],
#  ['en quoi consiste le master ?', '6 mois de cours et 5 mois de stage'],
#  ['salut', 'bonjour'],
#  ['pourquoi il y a plusieurs parcours ?',
#   'les deux parcours proposes permettent d adapter l enseignement aux etudiants suivant leur profil'],
#  ['quelle est la difference entre le parcours info et math ?',
#   'le contenu est le meme seules les ue de remise a niveau sont differentes'],
#  ['et on peut candidater aux deux parcours ?',
#   'en principe oui mais sachez que chaque parcours possede ses propres prerequis'],
#  ['mes salutations', 'bonjour'],
#  ['et est-ce qu on peut s inscrire aux deux parcours ?',
#   'en principe oui mais sachez que chaque parcours possede ses propres prerequis'],
#  ['je n ai pas de lettre de recommendation', 'ce n est pas un probleme'],
#  ['est-ce qu il y a des options a suivre ?',
#   'certaines options du master 1 informatique sont conseillees referez vous a la page web'],
#  ['il y a une difference entre le parcours info et math ?',
#   'le contenu est le meme seules les ue de remise a niveau sont differentes'],
#  ['l vaut mieux faire le parcours informatique ou mathematiques ?',
#   'le contenu est le meme seules les ue de remise a niveau sont differentes'],
#  ['il y a des projets a rendre ?', 'oui plusieurs projets sont a rendre'],
#  ['faut-il faire un pfe ?',
#   'oui vous devez realiser plusieurs projets en binome'],
#  ['j aimerais savoir si il y a des projets durant l annee ?',
#   'oui vous devrez realiser plusieurs projets de fin d etude'],
#  ['le projet est-il encadre par des chercheurs du laboratoire ?',
#   'oui vous serez encadre par les enseignants chercheurs'],
#  ['on doit faire un projet de fin d etudes ?',
#   'plusieurs projets de fin d etudes seront a rendre'],
#  ['combien de projets il y a ?',
#   'il y a un projet a faire dans la plupart des ue'],
#  ['combien de projets sont a rendre ?',
#   'il y a un projet a faire dans la plupart des ue'],
#  ['il y a qu un seul projet ?', 'non plusieurs projets sont a rendre'],
#  ['il y a plusieurs projets a rendre ?', 'oui tout a fait'],
#  ['quels types de projets sont a faire ?',
#   'ce sont des mini-projets a rendre dans pratiquement chaque ue'],
#  ['quel genre de projets sont a rendre ?',
#   'ce sont des mini-projets a rendre dans pratiquement chaque ue'],
#  ['est-ce que les projets sont transversaux entre ue ?',
#   'non les projets concernent chacun une seule ue'],
#  ['est-ce que les projets concernent plusieurs ue ?',
#   'non les projets concernent chacun une seule ue'],
#  ['est-ce que c est un gros projet a rendre ?',
#   'non ce sont plusieurs mini-projets a rendre'],
#  ['il faut faire un seul gros projet ?',
#   'non ce sont plusieurs mini-projets a rendre'],
#  ['on peut developper un projet perso ?',
#   'bien sur mais prennez garde a consacrer suffisament de temps aux enseignements'],
#  ['pourriez-vous me renseigner', 'oui volontier que desirez vous savoir ?'],
#  ['j ai besoin d aide', 'en quoi puis-je vous aider ?'],
#  ['j ai une question', 'je suis la pour vous aider'],
#  ['vous pouvez m aider ?', 'oui volontier que desirez vous savoir ?'],
#  ['j ai besoin d un renseignement', 'je suis la pour vous renseigner'],
#  ['j ai besoin de renseignements', 'je suis la pour vous renseigner'],
#  ['j ai des questions', 'je suis la pour vous aider'],
#  ['j aurais une question', 'je suis la pour vous aider'],
#  ['je peux vous poser une question ?',
#   'oui volontier que desirez vous savoir ?'],
#  ['je recherche des informations', 'je suis la pour vous aider'],
#  ['je suis un peu perdu', 'comment puis-je vous aider ?'],
#  ['il y a un stage a faire ?', 'oui il y a un stage a faire'],
#  ['il faut faire un stage ?', 'oui il y a un stage a faire'],
#  ['la duree du stage ?', 'le stage doit avoir une duree de 5 a 6 mois'],
#  ['le stage dure combien de temps ?',
#   'le stage doit avoir une duree de 4 a 6 mois'],
#  ['combien de temps dure le stage ?', 'le stage doit durer entre 4 et 6 mois'],
#  ['quelle est la date de fin du stage ?',
#   'le stage doit finir absolument avant le 30 septembre'],
#  ['quelle est la date de debut de stage ?',
#   'le stage ne peut commencer avant le mois de janvier'],
#  ['le stage est-il remunere ?', 'oui le stage est obligatoirement remunere'],
#  ['est-ce que le stage est paye ?',
#   'oui le stage est obligatoirement remunere'],
#  ['est-ce qu on est paye pendant le stage ?',
#   'oui le stage est obligatoirement remunere'],
#  ['combien on est paye pendant le stage ?',
#   'la paye minimale durant le stage est de 550 euros mensuels environ'],
#  ['quelle est la paye minimale pendant le stage ?',
#   'la paye minimale durant le stage est de 550 euros mensuels environ'],
#  ['quelle est la paye maximale pendant le stage ?',
#   'il n y a pas de paye maximale'],
#  ['a combien s eleve la gratification durant le stage ?',
#   'la paye minimale durant le stage est de 550 euros mensuels environ'],
#  ['quel est le salaire durant le stage ?',
#   'la paye minimale durant le stage est de 550 euros mensuels environ'],
#  ['est-ce qu on peut negocier la remuneration du stage ?',
#   'il faut voir cela avec l entreprise d accueil'],
#  ['est-ce qu il faut trouver un stage avant de faire l inscription ?',
#   'il n est pas necessaire de trouver un stage avant l inscription'],
#  ['comment trouver un stage ?',
#   'des offres de stage seront transmises aux etudiants au fur et a mesure'],
#  ['ou trouver un stage ?',
#   'des offres de stage seront transmises aux etudiants au fur et a mesure'],
#  ['quand est la soutenance de stage ?',
#   'le soutenances de stage se font debut septembre'],
#  ['quand faut-il rendre le rapport de stage ?',
#   'les rapports de stage sont a rendre vers la fin aout'],
#  ['comment je contacte le responsable du master ?',
#   'il faut se renseigner sur la page sitecontacts'],
#  ['comment je contacte la scolarite ?',
#   'il faut se renseigner sur la page sitecontacts'],
#  ['comment pourrais-je contacter la scolarite ?',
#   'il faut se renseigner sur la page sitecontacts'],
#  ['ou puis-je retirer ma carte etudiant ?',
#   'vous devriez poser la question au service de scolarite'],
#  ['ou je peux faire refaire ma carte etudiant ?',
#   'vous devriez poser la question au service de scolarite'],
#  ['est-tu un bot ?', 'effectivement je suis un bot'],
#  ['tu es un robot ?', 'effectivement je suis un robot'],
#  ['quel est ton nom ?', 'je m appelle nomchatbot'],
#  ['comment tu t appelle ?', 'je m appelle nomchatbot'],
#  ['tu t appelles comment ?', 'je m appelle nomchatbot'],
#  ['tu as un nom ?', 'oui je m appelle nomchatbot'],
#  ['qui est ton createur ?', 'navre je n ai pas la reponse a cette question'],
#  ['c est un formation de qualite', 'merci'],
#  ['c est un super master', 'merci'],
#  ['c est un master reconnu', 'oui il le devient'],
#  ['je n ai pas compris', 'excusez moi pouvez-vous reformuler votre requete ?'],
#  ['je n ai pas compris la reponse',
#   'excusez moi pouvez-vous reformuler votre requete ?'],
#  ['on est oblige de passer par ecandidat ?', 'oui c est obligatoire'],
#  ['il faut connaitre quel langage ?',
#   'vous aurez principalement besoin des langages python r et scala'],
#  ['quels sont les langages qu on va utiliser ?',
#   'vous utiliserez principalement les langages python r et scala'],
#  ['il y a d autres langages que du python ?',
#   'certains tp devront etre fait en r en scala ou en sas'],
#  ['il faut apprendre un langage en particulier ?',
#   'non mais vous pouvez essayer de vous perfectionner en python r ou scala'],
#  ['quels sont les langages de programmation utilises ?',
#   'vous utiliserez principalement les langages python r et scala'],
#  ['combien y a-t-il d ects par cours ?', 'chaque cours vaut trois ects'],
#  ['y a-t-il eu des redoublants les annees passees ?',
#   'il y a eu un seul redoublant'],
#  ['aurais-je des vacances ?', 'vous aurez malheureusement peu de vacances'],
#  ['c est plus facile pour les matheux ou les infos ?',
#   'chacun a ses facilites et ses difficultes'],
#  ['quel est la reputation du master ?', 'c est a vous de faire sa reputation'],
#  ['quel est le pourcentage d embauche en fin d etudes ?',
#   'en data sciences le taux d embauches est de 100%'],
#  ['comment sont les enseignants ?', 'a vous de vous faire votre avis '],
#  ['combien d etudiants ont rate l an dernier ?', 'un seul'],
#  ['peut-on suivre deux cursus en parallele ?',
#   'non sauf les etudiants de l ecl et polytech'],
#  ['quand faut-il commencer le stage ?', 'a partir de fin fevrier'],
#  ['proposez vous des theses dans le laboratoire de l universite ?',
#   'oui on en propose plusieurs'],
#  ['merci beaucoup', 'je vous en prie'],
#  ['quels sont les modules pour les etudiants de ecl ?',
#   'deux modules obligatoires pgm et mchine learning '],
#  ['ou trouver l emploi du temps data science ?', 'sur le site web'],
#  ['est ce que tout les cours sont sur le campus de villeubanne ?',
#   'ouisauf si vous suivez le master en commun avec ecl'],
#  ['aurons nous des ordinateurs pour les tp ?',
#   'oui des ordinateurs sont a votre disposition dans les salles de tps '],
#  ['quel est la proportion d etudiants de l insa lyon ?', 'un cinquieme '],
#  ['combien d etudiants viennent de l insa lyon ?', 'une dizaine '],
#  ['combien de stages proposes dans le domaine de la biologie ?',
#   'au moins 4 '],
#  ['quel est le systeme d exploitation prefere des professeurs ?', 'mac '],
#  ['quels sont les os les plus utilises par les etudiants ?', 'windows linux '],
#  ['combien de matieres choisies en moyenne par les etudiants en double cursus ?',
#   'huit '],
#  ['quel est le programme de statistiques ?',
#   'inference puis regression lineaire '],
#  ['combien d anecdotes par cours de machine learning en moyenne ?',
#   'au moins 3 '],
#  ['quelle est la moyenne de la promotion ?', '12 '],
#  ['quel est le salaire moyen annuel a la sortie ?', '30 000 euros '],
#  ['combien d offres de stage en sante ?', 'deux '],
#  ['bonjour je veux faire data science et j ai quelques questions a vous poser',
#   'je vous ecoute'],
#  ['bonjour', 'je suis a votre ecoute '],
#  ['je veux savoir les statistiques des annees precedentes dans l insertion professionnelle',
#   'il y a 100% d integration professionnelle en m2 ds '],
#  ['et a propos de la poursuite d etudes',
#   'le m2 ds permet egalement la poursuite en these '],
#  ['pouvez vous m envoyer la presentation du parcours sous forme de pdf ?',
#   'vous trouverez la presentation sur le site web du master'],
#  ['qui est le responsable de cette formation ?',
#   'c est monsieur alexandre aussem et le co-responsable est haytham elghazel'],
#  ['comment je fais pour deposer une candidature ?',
#   'vous trouverez ces informations sur le site web du master'],
#  ['est ce qu il y a un stage dans cette formation ?',
#   'oui il y a un stage a faire '],
#  ['un stage effectue en entreprise ?',
#   'les stages sont effectues en entreprise ou dans un laboratoire de recherche'],
#  ['un stage effectue en laboratoire ?',
#   'les stages sont effectues en entreprise ou dans un laboratoire de recherche'],
#  ['est ce que le stage est obligatoire ?',
#   'oui la validation d un stage est obligatoire '],
#  ['merci pour votre temps', ' bonne journee '],
#  ['c est tout ce que j ai comme question', ' bonne journee '],
#  ['est-il possible de redoubler le master 2 ?', 'non '],
#  ['le master 2 data science est-il a finalite recherche ou professionnelle ?',
#   'il est a finalite professionnelle '],
#  ['est-il possible de poursuivre en these apres le m2 ?', 'oui '],
#  ['quels masters mathematiques proposent une alternance ?', 'le master sitn '],
#  ['y a-t-il des specialisations pour le master 2 data science ?',
#   'non seul le master 2 maths en action proposent des specialisations '],
#  ['faut-il un bon niveau d informatique pour suivre le master 2 data science ?',
#   'il sera demande de maitriser plusieurs logiciels et systemes d exploitation '],
#  ['le master 2 data science est-il recent ?', 'oui il a 3 ans '],
#  ['et les credits par matiere ?',
#   ' developpement informatique vaut 6 credits et le stage vaut 21 credits '],
#  ['y a-t-il des projets dans le master 2 data science ?',
#   'oui le nombre de projets est assez important '],
#  ['jusqu a quelle date puis-je m inscrire ?', 'jusqu a juin'],
#  ['l inscription en ligne c est urgent ou on peut attendre ?',
#   'il ne faut pas depasser la date limite de l inscription '],
#  ['quel est le cout de la scolarite ?', 'il est de 400 euros '],
#  ['ca coute combien de faire ce master ?', 'ca coute 400 euros '],
#  ['quels sont les modes de paiement possibles ?',
#   'vous pouvez payer par carte par cheque bancaire par virement ou en espece '],
#  ['quelles sont les dates de toutes les vacances de cette annee scolaire ?',
#   'vous pouvez consulter le planning sur le site web '],
#  ['quelle est la duree minimale de stage de fin d etude ?',
#   'les stages sont d une duree entre 5 et 6 mois '],
#  ['quand doit on commencer le stage de fin d etude ?',
#   'le stage commence au debut de mars '],
#  ['y-aura t-il une ceremonie de remise des diplome ?', 'oui bien-sur '],
#  ['est-ce qu il y a un stage obligatoire en fin d annee ?',
#   'oui de six mois a partir de mars'],
#  ['est-il possible d avoir la maquette detaillee de ce master ?',
#   'oui je vous l ai envoyee en piece jointe'],
#  ['ce master propose une alternance ?', 'non'],
#  ['ou est-ce que je peux m inscrire ?', 'il faut contacter la scolarite'],
#  ['quelle est le deroulement du master ?',
#   '6 mois de cours et 5 mois de stage'],
#  ['comment se deroule le master ?', '6 mois de cours et 5 mois de stage'],
#  ['est-il dur de trouver un stage ?',
#   'des offres de stage seront transmises aux etudiants au fur et a mesure'],
#  ['quel est le niveau du master ?', 'le niveau est plutot bon'],
#  ['peut-on poursuivre en these ?', 'oui c est possible apres le master'],
#  ['est-ce qu il y a des forums entreprise pour le master data science ?',
#   'oui il y a un forum entreprise lyon 1'],
#  ['un forum entreprise ?',
#   'oui vous pourrez rentrer en communication avec plusieurs intervenants d entreprises '],
#  ['est-ce que le master 2 data science est en partenariat avec des entreprises ?',
#   'il y a des collaborations etroites avec des entreprises '],
#  ['je veux savoir encore plus sur la formation',
#   'pour en savoir plus veuillez visiter notre site web '],
#  ['je suis etudiant etranger',
#   'veuillez vous renseigner sur la procedure campus france'],
#  ['on peut faire du sport ?', 'oui basketball football rugby tennis etc'],
#  ['peut-on adherer a une association ?',
#   'oui a lyon 1 il y a l association des informaticiens lyonnais'],
#  ['peut-on s adherer a un club ?',
#   'oui a lyon 1 il y a l association des informaticiens lyonnais'],
#  ['est-ce qu il y a un restaurant universitaire juste a cotee?',
#   'oui il y a des restaurants universitaires a proximite'],
#  ['est-ce qu il y a une salle de jeu ?', 'non'],
#  ['est-ce qu il y a un babyfoot ?', 'non', ''],
#  ['est-ce qu il y a une table de billard ?', 'non'],
#  ['je suis etranger dois-je passer le toeic obligatoirement ?',
#   'non le niveau b1 du toeic est exige seulement pour les etudiants francais'],
#  ['peut-on commencer le stage avant le 1er mars ?',
#   'oui vous pourriez commencer le stage juste apres que les cours se terminent '],
#  ['la formation du master 2 data science aura lieu ou precisement ?',
#   'la formation master 2 data science aura lieu au batiment nautibus '],
#  ['est-ce que je peux passer le toeic gratuitement ?',
#   'oui pour le premier passage le toeic est gratuit '],
#  ['quels sont les perspectives de la formation ?',
#   'faire une these ou exercer le metier de data scientist'],
#  ['quels sont les demarches de candidature pour un etudiant international ?',
#   'les etudiants etrangers passent par une etude dossier et un entretien de motivation '],
#  ['le stage est-il obligatoire en entreprise ?',
#   'non il est possible de l effectuer en laboratoire '],
#  ['la formation peut elle avoir lieu en alternance ?', 'non'],
#  ['aurais-je besoin des cours de soutien ?',
#   'non les cours magistraux et seance de td tp sont suffisants'],
#  ['il y a des cours de data mining ?', 'oui'],
#  ['il y a une mise a niveau en informatique ?',
#   'oui pour les etudiants option maths'],
#  ['il y a des comptes rendus et rapports a rendre ?',
#   'oui une fois les tps ou projets acheves'],
#  ['l evaluation a lieu de maniere reguliere ou en fin de semestre ?',
#   'les etudiants passent des controles continus chaque mois dans les differentes disciplines'],
#  ['un stage d insertion professionnelle ?',
#   'oui un stage de recherche ou d insertion professionnelle'],
#  ['est ce que c est un stage pre-embauche ?',
#   'bien sur ce stage sera de la pre embauche'],
#  ['vous encourager le travail ?',
#   'nous ne sommes pas pour la precarisation du travail '],
#  ['ou se trouve l offre de travail ?',
#   'l offre se situe a proximite de la defence a paris '],
#  ['quelle est la duree de stage ?', 'la duree du stage et d au moins 6 mois '],
#  ['quelle est la taille de l equipe de travail ?',
#   ' la taille de l equipe est de 20 personnes '],
#  ['quel est le secteur d activite ?',
#   ' le stage est lie au secteur bancaire '],
#  ['quel est le sujet du stage ?',
#   'le sujet tourne autour du developpement d un chatbot '],
#  ['bonjour', 'bonjour puis je vous aider?'],
#  ['comment integrervotre master data science ?',
#   'il faut candidater sur le site'],
#  ['puis je l integrer quand je suis etranger ?',
#   'oui absolument tant que vous etes autorises'],
#  ['les etrangers suivent ils le meme format d inscription ?',
#   'si vous etes en france oui sinon vous pouvez regarder sur internet '],
#  ['je suis deja en france ?', 'dans ce cas etes vous de lyon1 ?'],
#  ['je suis de lyon 1',
#   'postulez dans ce cas directement sur ecandidat lyon 1'],
#  ['merci de votre aide', 'je suis la pour ca a la prochaine'],
#  ['bonjour', 'bonjour'],
#  ['je suis de centrale puis-je suivre le m2 data science ?',
#   'quelle est votre option a centrale ?'],
#  ['je fais ecl en informatique', 'vous pouvez suivre le m2 data science'],
#  ['comment faire pour s inscrire venant de centrale ?',
#   'il faut deposer un dossier de candidature aupres de votre etablissement '],
#  ['quelles seront les matieres enseignees en double parcours ?',
#   'machine learning et modeles graphiques probabilistes'],
#  ['quelles seront les matieres enseignees en venant de centrale ?',
#   'machine learning et modeles graphiques probabilistes'],
#  ['quelles seront les matieres enseignees en venant de l ecl ?',
#   'machine learning et modeles graphiques probabilistes'],
#  ['qui est le professeur principal ?',
#   '',
#   'le professeur est monsieur aussem'],
#  ['les partiels sont-ils surs ?',
#   'en etant regulier et serieux vous devriez vous en sortir'],
#  ['les partiels sont-ils difficile ?',
#   'en etant regulier et serieux vous devriez vous en sortir'],
#  ['quels competences sont necessaires pour integrer le master ?',
#   'mathematiques et statistiques'],
#  ['est ce que le master propose un enseignement en big data?',
#   'oui il y a un cours en big data'],
#  ['avons nous la possibilite d effectuer un stage lors du master?',
#   'oui de six mois a partir de mars'],
#  ['comment s inscrire au master?',
#   'les inscriptions 2019 se font sur ecandidat'],
#  ['y a t il des cours le week-end ?', 'non mais la bu est ouverte'],
#  ['quelle est la remuneration minimale d un stagiaire ?',
#   'la paye minimale durant le stage est de 550 euros mensuels environ'],
#  ['ce master permet il de faire une these ?',
#   'oui c est possible apres le master'],
#  ['y a t il des cours de mise a jour en informatique ?',
#   'oui pour les etudiants de ds math'],
#  ['recevons nous obligatoirement une remuneration pour le stage ?',
#   'oui le stage est obligatoirement remunere'],
#  ['quand pouvons nous commencer le stage ?', 'le commence en mars '],
#  ['quel est l effectif de la promotion en mathematiques de l an dernier ?',
#   '16 etudiants en ds info'],
#  ['comment peut-on candidater ?', 'sur le site du master '],
#  ['est-ce que lyon est une ville etudiante ?',
#   'oui elle a ete elu meilleure ville etudiante 2018 '],
#  ['quelle pre-requis faut-il avoir pour acceder au master ?',
#   'cela depend des parcours '],
#  ['les matieres se compensent-elles entre elles ?', 'oui '],
#  ['faut il valider toutes les matieres pour valider le master ?',
#   'cela depend des parcours '],
#  ['quel differences entres les parcours ?',
#   'quelques matieres different il faut regarder sur le site du master '],
#  ['qu est-ce que la data visualization ?', 'c est pour visualiser les data '],
#  ['y a-t-il des options ?', 'non c est un tronc commun'],
#  ['comment trouver un stage ?', 'vous recevrez de nombreuses offres'],
#  ['qu est ce que le machine learning ?',
#   'vous aurez l occasion de le decouvrir '],
#  ['est-il necessaire d avoir un bon ordinateur ?', 'non mais c est mieux'],
#  ['y a-t-il des cours de deep learning ?',
#   ' pas specifiquement mais vous aurez l occasion d en parler'],
#  ['est-il difficile de trouver un stage ?',
#   'non les offres de stages sont nombreuses'],
#  ['y a-t-il des debouches ?', 'oui surtout en machine learning'],
#  ['quelle est la taille de la promotion ?',
#   'les promotions comptent environ 20 personnes'],
#  ['y a-t-il beaucoup de mathematiques ?', 'a peu pres 50%'],
#  ['doit-on obligatoirement faire un stage ?',
#   'oui de six mois a partir de mars'],
#  ['le toeic est-il obligatoire ?',
#   'oui il est obligatoire pour valider le master'],
#  ['peut-on poursuivre en these ?',
#   'oui il est possible de poursuivre en these academique ou cifre'],
#  ['quels langages de programmation faut-il connaitre ?',
#   'vous aurez principalement besoin des langages python r et scala'],
#  ['combien de temps dure le stage ?', 'entre 5 et 6 mois'],
#  ['comment candidater ?', 'il faut le faire sur ecandidat '],
#  ['y a t-il des options ?',
#   'non mais les matieres sont differentes selon les parcours '],
#  ['pourquoi faire ce master ?', 'pour se former au metier de data scientist'],
#  ['ou se situe les locaux du master ?', 'sur le site de la doua '],
#  ['proposez-vous des stages ?', 'il faut contacter la scolarite'],
#  ['sommes-nous facilement recruter a la sortie du master ?', 'oui'],
#  ['est-ce que tous les cours sont sur le site de la doua ?', 'oui'],
#  ['combien y a de cours par semaine ?', 'il faut contacter la scolarite'],
#  ['quels sont les stages qui ont deja ete fait ?',
#   'il faut contacte la scolarite'],
#  ['y a t-il d autres master data science en france ?', 'oui'],
#  ['quels sont les logiciels utilises pour le parcours informatique ?',
#   'python principalement'],
#  ['c est quand les dates des stages ?', 'en mars'],
#  ['puis-je suivre ce master sans avoir fait de cours similaires avant ?',
#   'oui pourvu que vous ayez un bagage suffisant en mathematiques et informatique '],
#  ['le stage de fin d etudes doit etre oriente recherche uniquement ?',
#   'le stage peut etre applicatif pourvu qu il y ait une demarche de recherche '],
#  ['etes-vous un chatbot ou un humain ?',
#   'je vous laisse deviner je ne ferai pas de test de turing aujourd hui '],
#  ['j aime beaucoup les mathematiques et je m interesse a l extraction de connaissances',
#   'ce master est fait pour vous',
#   ''],
#  ['a-t-on de bonnes chances d etre recrute a l issu de ce master ?',
#   'la data science est un domaine en pleine expansion les debouches sont nombreux '],
#  ['je ne vois pas de module de deep learning dans le programme du master',
#   'les reseaux de neurones sont abordes en machine learning notamment '],
#  ['les reseaux de neurones sont-ils abordes dans le parcours data science ?',
#   'les reseaux de neurones sont abordes en machine learning notamment '],
#  ['y a-t-il des machines a cafe dans le batiment nautibus ?',
#   'oui il y en a meme sur tout le campus '],
#  ['le parcours est-il ouvert aux etudiants etrangers ?',
#   ' les etudiants etrangers peuvent s inscrire '],
#  ['quels sont les debouches possibles ?', 'le metier de data scientist'],
#  ['y a t il des abandons durant l annee ?', 'c est assez rare'],
#  ['quels sont les differences avec le master ia ?',
#   'le master ds est plus oriente machine learning et big data'],
#  ['faut-il etre bon en maths ?', 'c est preferable il y a des rappels '],
#  ['sur quels sujets faut-il se mettre a jour en maths ?',
#   'les statistiques et les probabilites'],
#  ['faut-il etre bon en anglais ?',
#   'il faut obtenir le niveau b1 au toeic pour valider le master'],
#  ['quel est le niveau en anglais ?',
#   'il faut obtenir le niveau b1 au toeic pour valider le master'],
#  ['qui est le responsable du master ?',
#   'il faut se renseigner sur la page sitecontacts'],
#  ['combien y a t il de places ?', 'il y a 20 places en tout'],
#  ['quels sont les 3 lois de la robotique ?',
#   'on me les a apprise mais j ai oublie'],
#  ['quel est le professeur de machine learning ?', 'alexandre aussem'],
#  ['est-il possible de suivre la formation en alternance ?',
#   'non ce n est pas possible'],
#  ['le master est-il plutot oriente maths ou infos ?',
#   'le master est moitie maths moitie info '],
#  ['faut-il avoir suivi des cours de statistiques pour postuler ?',
#   'non une mise a niveau sera faite en debut d annee '],
#  ['y a-t-il des cours de dataviz ?', 'oui c est au programme du master '],
#  ['comment allez-vous ?', 'tres bien je vous remercie '],
#  ['il fait beau aujourd hui', 'oui le soleil est radieux '],
#  ['faut-il faire un stage en fin d annee ?',
#   'oui le stage est obligatoire pour valider le m2 '],
#  ['combien de temps doit durer le stage ?', 'entre 5 et 6 mois '],
#  ['faut-il avoir un ordinateur personnel ?',
#   'ce n est pas obligatoire mais fortement recommande '],
#  ['combien de temps durent les pauses entre 2 cours ?',
#   'les pausent durent 15min '],
#  ['combien d etages ont les batiments de cours ?',
#   'les batiments ont 2 etages '],
#  ['la vue par la fenetre est elle belle ?',
#   'oui si on sait apprecier le charme d un parking '],
#  ['les professeur sont-ils des chercheurs dans leur domaine ?', 'oui '],
#  ['est ce qu un batiments risque d exploser comme a la doua ?',
#   'non ici rien d explosif '],
#  ['qui est le responsable du master ?', 'alexandre aussem'],
#  ['si je ne viens pas de lyon ?',
#   'cinq places pour les titulaires d un master francais'],
#  ['les cours sont en quelle langue ?',
#   'en francais avec support ecrit anglais'],
#  ['faut il parler anglais ?',
#   'le niveau b2 du toeic est requis pour valider le master'],
#  ['a t-on a choisir entre certaines matieres ?',
#   'non toutes les matieres sont obligatoires'],
#  ['les matieres sont en controle continu ?', 'cela depend des matieres'],
#  ['il y a des rattrapages ?', 'cela depend des matieres'],
#  ['quelles sont les horaires ?',
#   'cela depend des jours voir la page planning'],
#  ['faut il avoir son propre pc ?', 'c est conseille mais pas obligatoire'],
#  ['quel est le cout du master ?',
#   'vous devriez poser la question au service de scolarite'],
#  ['qui a developpe le chatbot ?',
#   'c est mr aussem qui a developpe le chatbot '],
#  ['qui a programme le chatbot ?',
#   'c est mr aussem qui a developpe le chatbot '],
#  ['je parle a qui ?', 'je suis le chatbot du master data science de lyon 1 '],
#  ['qui es-tu ?', '', 'je suis le chatbot du master data science de lyon 1 '],
#  ['qui etes-vous ?', 'je suis le chatbot du master data science de lyon 1 '],
#  ['a qui je parle ?', 'je suis le chatbot du master data science de lyon 1 '],
#  ['je n ai pas compris',
#   'je suis le chatbot du master data science de lyon 1 '],
#  ['je ne comprends rien a votre reponse ?',
#   'je suis le chatbot du master data science de lyon 1 '],
#  ['qui est ton chef ?', 'c est mr aussem qui a developpe le chatbot '],
#  ['qui est ton dieu ?', 'c est mr aussem qui a developpe le chatbot '],
#  ['qui t a cree ?', 'c est mr aussem qui a developpe le chatbot '],
#  ['je parle a une machine ?', 'c est mr aussem qui a developpe le chatbot '],
#  ['tu es un bot ?', 'c est mr aussem qui a developpe le chatbot '],
#  ['bot ?', 'c est mr aussem qui a developpe le chatbot '],
#  ['tu sais dire autre chose ?', 'non je ne suis qu un chatbot '],
#  ['tu sais parler ?', 'non je ne suis qu un chatbot '],
#  ['parle moi de quelque chose d autre', 'non je ne suis qu un chatbot '],
#  ['dites-moi quelque chose d autre', 'non je ne suis qu un chatbot ']]

# %% [markdown]
# The Seq2Seq Model
# =================
#
# A Recurrent Neural Network, or RNN, is a network that operates on a
# sequence and uses its own output as input for subsequent steps.
#
# A `Sequence to Sequence network <http://arxiv.org/abs/1409.3215>`__, or
# seq2seq network, or `Encoder Decoder
# network <https://arxiv.org/pdf/1406.1078v3.pdf>`__, is a model
# consisting of two RNNs called the encoder and decoder. The encoder reads
# an input sequence and outputs a single vector, and the decoder reads
# that vector to produce an output sequence.
#
# Unlike sequence prediction with a single RNN, where every input
# corresponds to an output, the seq2seq model frees us from sequence
# length and order, which makes it ideal for dialogue systems.
#
# With a seq2seq model the encoder creates a single vector which, in the
# ideal case, encodes the "meaning" of the input sequence into a single
# vector — a single point in some N dimensional space of sentences.

# %% [markdown]
# The Encoder
# -----------
#
# The encoder of a seq2seq network is a RNN that outputs some value for
# every word from the input sentence. For every input word the encoder
# outputs a vector and a hidden state, and uses the hidden state for the
# next input word.

# %%
class EncoderRNN(nn.Module):
    def __init__(self, input_size, hidden_size, n_layers=1):
        super(EncoderRNN, self).__init__()
        self.n_layers = n_layers
        self.hidden_size = hidden_size

        self.embedding = nn.Embedding(input_size, hidden_size)
        self.gru = nn.GRU(hidden_size, hidden_size)

    def forward(self, input, hidden):
        embedded = self.embedding(input).view(1, 1, -1)
        output = embedded
        for i in range(self.n_layers):
            output, hidden = self.gru(output, hidden)
        return output, hidden

    def initHidden(self):
        result = Variable(torch.zeros(1, 1, self.hidden_size))
        return result

# %% [markdown]
# A standard RNN Decoder
# -----------
#
# The decoder is another RNN that takes the encoder output vector(s) and
# outputs a sequence of words to produce the answer.

# %% [markdown]
# **Simple Decoder**
#
# In the simplest seq2seq decoder we use only last output of the encoder.
# This last output is sometimes called the *context vector* as it encodes
# context from the entire sequence. This context vector is used as the
# initial hidden state of the decoder.
#
# At every step of decoding, the decoder is given an input token and
# hidden state. The initial input token is the start-of-string ``<SOS>``
# token, and the first hidden state is the context vector (the encoder's
# last hidden state).

# %%
class DecoderRNN(nn.Module):
    def __init__(self, hidden_size, output_size, n_layers=1):
        super(DecoderRNN, self).__init__()
        self.n_layers = n_layers
        self.hidden_size = hidden_size

        self.embedding = nn.Embedding(output_size, hidden_size)
        self.gru = nn.GRU(hidden_size, hidden_size)
        self.out = nn.Linear(hidden_size, output_size)
        self.softmax = nn.LogSoftmax(dim=1)

    def forward(self, input, hidden):
        output = self.embedding(input).view(1, 1, -1)
        for i in range(self.n_layers):
            output = F.relu(output)
            output, hidden = self.gru(output, hidden)
        output = self.softmax(self.out(output[0]),dim=1)
        return output, hidden

    def initHidden(self):
        result = Variable(torch.zeros(1, 1, self.hidden_size))
        return result

# %% [markdown]
# # Attention Decoder
#
#
# If only the context vector is passed betweeen the encoder and decoder,
# that single vector carries the burden of encoding the entire sentence.
#
# Attention allows the decoder network to "focus" on a different part of
# the encoder's outputs for every step of the decoder's own outputs. First
# we calculate a set of *attention weights*. These will be multiplied by
# the encoder output vectors to create a weighted combination. The result
# (called ``attn_applied`` in the code) should contain information about
# that specific part of the input sequence, and thus help the decoder
# choose the right output words.
#
# Calculating the attention weights is done with another feed-forward
# layer ``attn``, using the decoder's input and hidden state as inputs.
# Because there are sentences of all sizes in the training data, to
# actually create and train this layer we have to choose a maximum
# sentence length (input length, for encoder outputs) that it can apply
# to. Sentences of the maximum length will use all the attention weights,
# while shorter sentences will only use the first few.

# %%
class AttnDecoderRNN(nn.Module):
    def __init__(self, hidden_size, output_size, n_layers=1, dropout_p=0.1, max_length=MAX_LENGTH):
        super(AttnDecoderRNN, self).__init__()
        self.hidden_size = hidden_size
        self.output_size = output_size
        self.n_layers = n_layers
        self.dropout_p = dropout_p
        self.max_length = max_length

        self.embedding = nn.Embedding(self.output_size, self.hidden_size)
        self.attn = nn.Linear(self.hidden_size * 2, self.max_length)
        self.attn_combine = nn.Linear(self.hidden_size * 2, self.hidden_size)
        self.dropout = nn.Dropout(self.dropout_p)
        self.gru = nn.GRU(self.hidden_size, self.hidden_size)
        self.out = nn.Linear(self.hidden_size, self.output_size)

    def forward(self, input, hidden, encoder_outputs):
        embedded = self.embedding(input).view(1, 1, -1)
        embedded = self.dropout(embedded)

        attn_weights = F.softmax(
            self.attn(torch.cat((embedded[0], hidden[0]), 1)))#, dim=1)
        attn_applied = torch.bmm(attn_weights.unsqueeze(0),
                                 encoder_outputs.unsqueeze(0))

        output = torch.cat((embedded[0], attn_applied[0]), 1)
        output = self.attn_combine(output).unsqueeze(0)

        for i in range(self.n_layers):
            output = F.relu(output)
            output, hidden = self.gru(output, hidden)

        output = F.log_softmax(self.out(output[0]))#, dim=1)
        return output, hidden, attn_weights

    def initHidden(self):
        result = Variable(torch.zeros(1, 1, self.hidden_size))
        return result

# %% [markdown]
# Note: There are other forms of attention that work around the length
#   limitation by using a relative position approach. Read about "local
#   attention" in `Effective Approaches to Attention-based Neural Machine
#   Translation <https://arxiv.org/abs/1508.04025>`
#
# # Training
#
#
# Preparing Training Data
# -----------------------
#
# To train, for each pair we will need an input tensor (indexes of the
# words in the input sentence) and target tensor (indexes of the words in
# the target sentence). While creating these vectors we will append the
# EOS token to both sequences.

# %%
def indexesFromSentence(lang, sentence):
    return [lang.word2index[word] for word in sentence.split()]

def variableFromSentence(lang, sentence):
    indexes = indexesFromSentence(lang, sentence)
    indexes.append(EOS_token)
    result = Variable(torch.LongTensor(indexes).view(-1, 1))
    return result

def variablesFromPair(pair):
    input_variable = variableFromSentence(input_lang, pair[0])
    target_variable = variableFromSentence(output_lang, pair[1])
    return (input_variable, target_variable)

# %% [markdown]
# Training the Model
# ------------------
#
# To train we run the input sentence through the encoder, and keep track
# of every output and the latest hidden state. Then the decoder is given
# the ``<SOS>`` token as its first input, and the last hidden state of the
# encoder as its first hidden state.
#
# "Teacher forcing" is the concept of using the real target outputs as
# each next input, instead of using the decoder's guess as the next input.
# Using teacher forcing causes it to converge faster but `when the trained
# network is exploited, it may exhibit
# instability <http://minds.jacobs-university.de/sites/default/files/uploads/papers/ESNTutorialRev.pdf>`.
#
# You can observe outputs of teacher-forced networks that read with
# coherent grammar but wander far from the correct answer -
# intuitively it has learned to represent the output grammar and can "pick
# up" the meaning once the teacher tells it the first few words, but it
# has not properly learned how to create the sentence from the answer
# in the first place.
#
# Because of the freedom PyTorch's autograd gives us, we can randomly
# choose to use teacher forcing or not with a simple if statement. Turn
# ``teacher_forcing_ratio`` up to use more of it.

# %%
teacher_forcing_ratio = 0.5

def train(input_variable, target_variable, encoder, decoder, encoder_optimizer, decoder_optimizer, criterion, max_length=MAX_LENGTH):
    encoder_hidden = encoder.initHidden()

    encoder_optimizer.zero_grad()
    decoder_optimizer.zero_grad()

    input_length = input_variable.size()[0]
    target_length = target_variable.size()[0]

    encoder_outputs = Variable(torch.zeros(max_length, encoder.hidden_size))

    loss = 0

    for ei in range(input_length):
        encoder_output, encoder_hidden = encoder(
            input_variable[ei], encoder_hidden)
        encoder_outputs[ei] = encoder_output[0][0]

    decoder_input = Variable(torch.LongTensor([[SOS_token]]))
    decoder_input = decoder_input

    decoder_hidden = encoder_hidden

    use_teacher_forcing = True if random.random() < teacher_forcing_ratio else False

    if use_teacher_forcing:
        # Teacher forcing: Feed the target as the next input
        for di in range(target_length):
            
            decoder_output, decoder_hidden, decoder_attention = decoder(
                decoder_input, decoder_hidden, encoder_outputs)
            
            #decoder_output, decoder_hidden = decoder(
             #   decoder_input, decoder_hidden)
            
            loss += criterion(decoder_output, target_variable[di])
            decoder_input = target_variable[di]  # Teacher forcing

    else:
        # Without teacher forcing: use its own predictions as the next input
        for di in range(target_length):
            
            decoder_output, decoder_hidden, decoder_attention = decoder(
                decoder_input, decoder_hidden, encoder_outputs)
            
            #decoder_output, decoder_hidden = decoder(
             #   decoder_input, decoder_hidden)       
            
            topv, topi = decoder_output.data.topk(1)
            ni = topi[0][0].item()

            decoder_input = Variable(torch.LongTensor([[ni]]))
            decoder_input = decoder_input

            loss += criterion(decoder_output, target_variable[di])
            if ni == EOS_token:
                break

    loss.backward()

    encoder_optimizer.step()
    decoder_optimizer.step()

    #return loss.data[0] / target_length
    return loss.item() / target_length

# %% [markdown]
# This is a helper function to print time elapsed and estimated time
# remaining given the current time and progress %.

# %%
import time
import math

def asMinutes(s):
    m = math.floor(s / 60)
    s -= m * 60
    return '%dm %ds' % (m, s)

def timeSince(since, percent):
    now = time.time()
    s = now - since
    es = s / (percent)
    rs = es - s
    return '%s (- %s)' % (asMinutes(s), asMinutes(rs))

# %% [markdown]
# The whole training process looks like this:
#
# -  Start a timer
# -  Initialize optimizers and criterion
# -  Create set of training pairs
# -  Start empty losses array for plotting
#
# Then we call ``train`` many times and occasionally print the progress (%
# of examples, time so far, estimated time) and average loss.

# %%
def trainIters(encoder, decoder, n_iters, print_every=1000, plot_every=100, learning_rate=0.01):
    start = time.time()
    plot_losses = []
    print_loss_total = 0  # Reset every print_every
    plot_loss_total = 0  # Reset every plot_every

    encoder_optimizer = optim.SGD(encoder.parameters(), lr=learning_rate)
    decoder_optimizer = optim.SGD(decoder.parameters(), lr=learning_rate)
    
    training_pairs = [variablesFromPair(random.choice(pairs))
                      for i in range(n_iters)]
    criterion = nn.NLLLoss()

    for iter in range(1, n_iters + 1):
        training_pair = training_pairs[iter - 1]
        input_variable = training_pair[0]
        target_variable = training_pair[1]

        loss = train(input_variable, target_variable, encoder,
                     decoder, encoder_optimizer, decoder_optimizer, criterion)
        print_loss_total += loss
        plot_loss_total += loss

        if iter % print_every == 0:
            print_loss_avg = print_loss_total / print_every
            print_loss_total = 0
            print('%s (%d %d%%) %.4f' % (timeSince(start, iter / n_iters),
                                         iter, iter / n_iters * 100, print_loss_avg))

        if iter % plot_every == 0:
            plot_loss_avg = plot_loss_total / plot_every
            plot_losses.append(plot_loss_avg)
            plot_loss_total = 0

    showPlot(plot_losses)

# %% [markdown]
# Plotting results
# ----------------
#
# Plotting is done with matplotlib, using the array of loss values
# ``plot_losses`` saved while training.

# %%
import matplotlib.pyplot as plt
import matplotlib.ticker as ticker
import numpy as np


def showPlot(points):
    plt.figure()
    fig, ax = plt.subplots()
    # this locator puts ticks at regular intervals
    loc = ticker.MultipleLocator(base=0.2)
    ax.yaxis.set_major_locator(loc)
    plt.plot(points)

# %% [markdown]
# Evaluation
# ==========
#
# Evaluation is mostly the same as training, but there are no targets so
# we simply feed the decoder's predictions back to itself for each step.
# Every time it predicts a word we add it to the output string, and if it
# predicts the EOS token we stop there. We also store the decoder's
# attention outputs for display later.

# %%
def evaluate(encoder, decoder, sentence, max_length=MAX_LENGTH):
    input_variable = variableFromSentence(input_lang, sentence)
    input_length = input_variable.size()[0]
    encoder_hidden = encoder.initHidden()

    encoder_outputs = Variable(torch.zeros(max_length, encoder.hidden_size))
    encoder_outputs = encoder_outputs

    for ei in range(input_length):
        encoder_output, encoder_hidden = encoder(input_variable[ei],
                                                 encoder_hidden)
        encoder_outputs[ei] = encoder_outputs[ei] + encoder_output[0][0]

    decoder_input = Variable(torch.LongTensor([[SOS_token]]))  # SOS
    decoder_input = decoder_input

    decoder_hidden = encoder_hidden

    decoded_words = []
    decoder_attentions = torch.zeros(max_length, max_length)

    for di in range(max_length):
        
        #decoder_output, decoder_hidden = decoder(
         #   decoder_input, decoder_hidden)

        decoder_output, decoder_hidden, decoder_attention = decoder(
            decoder_input, decoder_hidden, encoder_outputs)
        decoder_attentions[di] = decoder_attention.data

        topv, topi = decoder_output.data.topk(1)
        ni = topi[0][0].item()

        if ni == EOS_token:
            decoded_words.append('<EOS>')
            break
        else:
            decoded_words.append(output_lang.index2word[ni])

        decoder_input = Variable(torch.LongTensor([[ni]]))

    return decoded_words, decoder_attentions[:di + 1]
    #return decoded_words

# %% [markdown]
# We can evaluate random sentences from the training set and print out the
# input, target, and output to make some subjective quality judgements:

# %%
def evaluateRandomly(encoder, decoder, n=10):
    for i in range(n):
        pair = random.choice(pairs)
        print('>', pair[0])
        print('=', pair[1])
        
        output_words, attentions = evaluate(encoder, decoder, pair[0])
        #output_words = evaluate(encoder, decoder, pair[0])
     
        output_sentence = ' '.join(output_words)
        print('<', output_sentence)
        print('')

# %% [markdown]
# Training and Evaluating
# =======================
#
# With all these helper functions in place (it looks like extra work, but
# it's easier to run multiple experiments easier) we can actually
# initialize a network and start training.
#
# Remember that they are very few input sentences. For this small
# dataset we can use relatively small networks of 100 hidden nodes and a
# single GRU layer. After about 3 minutes on a MacBook CPU we'll get some
# reasonable results.
#
# .. Note::
#    If you run this notebook you can train, interrupt the kernel,
#    evaluate, and continue training later. Comment out the lines where the
#    encoder and decoder are initialized and run ``trainIters`` again.

# %%
hidden_size = 256
#hidden_size = 100
encoder1 = EncoderRNN(input_lang.n_words, hidden_size)

attn_decoder1 = AttnDecoderRNN(hidden_size, output_lang.n_words,
                               1, dropout_p=0.1)
#attn_decoder1 = DecoderRNN(hidden_size, output_lang.n_words,1)

#trainIters(encoder1, attn_decoder1, 75000, print_every=5000)
trainIters(encoder1, attn_decoder1, 10000, print_every=100)
# Out:
# 0m 2s (- 4m 48s) (100 1%) 4.1972
# 0m 4s (- 3m 59s) (200 2%) 3.1761
# 0m 7s (- 4m 6s) (300 3%) 3.7399
# 0m 9s (- 3m 53s) (400 4%) 3.6958
# 0m 12s (- 3m 49s) (500 5%) 3.7455
# 0m 14s (- 3m 43s) (600 6%) 3.6629
# 0m 16s (- 3m 33s) (700 7%) 3.1138
# 0m 17s (- 3m 26s) (800 8%) 3.4466
# 0m 20s (- 3m 24s) (900 9%) 3.6064
# 0m 22s (- 3m 20s) (1000 10%) 3.3812
# 0m 24s (- 3m 18s) (1100 11%) 3.5343
# 0m 26s (- 3m 15s) (1200 12%) 3.4055
# 0m 29s (- 3m 14s) (1300 13%) 3.4376
# 0m 31s (- 3m 11s) (1400 14%) 3.2695
# 0m 33s (- 3m 9s) (1500 15%) 2.9286
# 0m 35s (- 3m 6s) (1600 16%) 3.1501
# 0m 37s (- 3m 4s) (1700 17%) 3.3556
# 0m 39s (- 3m 1s) (1800 18%) 3.0554
# 0m 41s (- 2m 58s) (1900 19%) 3.1809
# 0m 44s (- 2m 57s) (2000 20%) 3.0521
# 0m 46s (- 2m 54s) (2100 21%) 3.0450
# 0m 48s (- 2m 51s) (2200 22%) 3.1133
# 0m 50s (- 2m 49s) (2300 23%) 2.8013
# 0m 52s (- 2m 47s) (2400 24%) 3.0227
# 0m 54s (- 2m 44s) (2500 25%) 2.9970
# 0m 57s (- 2m 42s) (2600 26%) 3.2678
# 0m 59s (- 2m 40s) (2700 27%) 2.5180
# 1m 1s (- 2m 38s) (2800 28%) 2.7865
# 1m 4s (- 2m 36s) (2900 28%) 2.8475
# 1m 6s (- 2m 34s) (3000 30%) 2.7254
# 1m 8s (- 2m 31s) (3100 31%) 2.5688
# 1m 10s (- 2m 29s) (3200 32%) 2.4788
# 1m 12s (- 2m 27s) (3300 33%) 2.6561
# 1m 14s (- 2m 25s) (3400 34%) 2.4343
# 1m 17s (- 2m 23s) (3500 35%) 2.2779
# 1m 19s (- 2m 20s) (3600 36%) 2.3753
# 1m 21s (- 2m 18s) (3700 37%) 2.4485
# 1m 23s (- 2m 16s) (3800 38%) 2.1893
# 1m 25s (- 2m 14s) (3900 39%) 2.2330
# 1m 28s (- 2m 12s) (4000 40%) 2.0639
# 1m 30s (- 2m 10s) (4100 41%) 2.1702
# 1m 32s (- 2m 8s) (4200 42%) 2.1973
# 1m 35s (- 2m 6s) (4300 43%) 2.0663
# 1m 37s (- 2m 4s) (4400 44%) 1.9880
# 1m 39s (- 2m 2s) (4500 45%) 1.6905
# 1m 42s (- 1m 59s) (4600 46%) 1.9024
# 1m 44s (- 1m 57s) (4700 47%) 1.6972
# 1m 46s (- 1m 55s) (4800 48%) 1.6471
# 1m 49s (- 1m 53s) (4900 49%) 1.5465
# 1m 51s (- 1m 51s) (5000 50%) 1.4833
# 1m 54s (- 1m 49s) (5100 51%) 1.6223
# 1m 56s (- 1m 47s) (5200 52%) 1.6999
# 1m 58s (- 1m 45s) (5300 53%) 1.7462
# 2m 1s (- 1m 43s) (5400 54%) 1.4266
# 2m 3s (- 1m 41s) (5500 55%) 1.1863
# 2m 6s (- 1m 39s) (5600 56%) 1.2506
# 2m 9s (- 1m 37s) (5700 56%) 1.3587
# 2m 11s (- 1m 35s) (5800 57%) 1.3761
# 2m 14s (- 1m 33s) (5900 59%) 1.2353
# 2m 16s (- 1m 31s) (6000 60%) 1.3597
# 2m 18s (- 1m 28s) (6100 61%) 1.2602
# 2m 22s (- 1m 27s) (6200 62%) 1.1511
# 2m 25s (- 1m 25s) (6300 63%) 1.2136
# 2m 27s (- 1m 22s) (6400 64%) 0.9676
# 2m 29s (- 1m 20s) (6500 65%) 1.0822
# 2m 31s (- 1m 18s) (6600 66%) 1.0224
# 2m 34s (- 1m 15s) (6700 67%) 1.0000
# 2m 36s (- 1m 13s) (6800 68%) 0.8655
# 2m 38s (- 1m 11s) (6900 69%) 0.7578
# 2m 40s (- 1m 8s) (7000 70%) 1.0720
# 2m 43s (- 1m 6s) (7100 71%) 0.8140
# 2m 45s (- 1m 4s) (7200 72%) 0.8005
# 2m 48s (- 1m 2s) (7300 73%) 0.7103
# 2m 50s (- 0m 59s) (7400 74%) 0.6732
# 2m 52s (- 0m 57s) (7500 75%) 0.6731
# 2m 55s (- 0m 55s) (7600 76%) 0.7193
# 2m 58s (- 0m 53s) (7700 77%) 0.7485
# 3m 0s (- 0m 50s) (7800 78%) 0.5698
# 3m 2s (- 0m 48s) (7900 79%) 0.6219
# 3m 5s (- 0m 46s) (8000 80%) 0.6746
# 3m 7s (- 0m 43s) (8100 81%) 0.4949
# 3m 9s (- 0m 41s) (8200 82%) 0.5488
# 3m 12s (- 0m 39s) (8300 83%) 0.6083
# 3m 15s (- 0m 37s) (8400 84%) 0.4711
# 3m 17s (- 0m 34s) (8500 85%) 0.4700
# 3m 20s (- 0m 32s) (8600 86%) 0.5149
# 3m 23s (- 0m 30s) (8700 87%) 0.4393
# 3m 25s (- 0m 28s) (8800 88%) 0.5036
# 3m 28s (- 0m 25s) (8900 89%) 0.2991
# 3m 31s (- 0m 23s) (9000 90%) 0.5374
# 3m 33s (- 0m 21s) (9100 91%) 0.6244
# 3m 36s (- 0m 18s) (9200 92%) 0.3993
# 3m 38s (- 0m 16s) (9300 93%) 0.4895
# 3m 40s (- 0m 14s) (9400 94%) 0.3598
# 3m 43s (- 0m 11s) (9500 95%) 0.5513
# 3m 45s (- 0m 9s) (9600 96%) 0.2950
# 3m 47s (- 0m 7s) (9700 97%) 0.4312
# 3m 49s (- 0m 4s) (9800 98%) 0.4674
# 3m 52s (- 0m 2s) (9900 99%) 0.3400
# 3m 54s (- 0m 0s) (10000 100%) 0.3375

# %%
evaluateRandomly(encoder1, attn_decoder1)
# Out:
# > quels sont les 3 lois de la robotique ?
# = on me les a apprise mais j ai oublie
# < on me les a apprise mais j ai oublie <EOS>
#
# > les cours-ils difficile a suivre ?
# = non mais il faut travailler assidument
# < non mais il faut travailler assidument <EOS>
#
# > ou puis-je retirer ma carte etudiant ?
# = vous devriez poser la question au service de scolarite
# < vous devriez poser la question au service de scolarite <EOS>
#
# > avez-vous une maquette detaillee de ce master ?
# = oui je vous l ai envoyee en piece jointe
# < oui je vous l ai envoyee en piece jointe <EOS>
#
# > et pour les inscriptions on fait comment ?
# = il faut contacter la scolarite
# < il faut contacter la scolarite <EOS>
#
# > le stage est-il obligatoire en entreprise ?
# = non il est possible de l effectuer en laboratoire
# < non il est possible de l effectuer en laboratoire <EOS>
#
# > j aimerais faire votre master
# = merci j en prends note
# < merci j en prends note <EOS>
#
# > est-ce qu on peut negocier la remuneration du stage ?
# = il faut voir cela avec l entreprise d accueil
# < il faut voir cela avec l entreprise d accueil <EOS>
#
# > aurais-je des vacances ?
# = les vacances ne doivent pas etre votre motivation
# < vous aurez malheureusement peu de vacances sur ecandidat <EOS>
#
# > combien on est paye pendant le stage ?
# = la paye minimale durant le stage est de 550 euros mensuels environ
# < la paye minimale durant le stage est de 550 euros mensuels environ <EOS>

# %% [markdown]
# New questions
# =========
#
# Ask new questions (never seen during training) using only the words that appear in your input vocabulary.

# %%
mail="Bonjour, je suis intéressé par la data science. C'est quand la rentrée ?\
Quels sont les cours enseignés  ? Quelle est la durée du stage ?\
On peut faire un stage recherche en laboratoire ? Merci monsieur."

sentences = [s.strip() for s in re.split('[\.\,\?\!]' , mail)]
print(sentences[:-1])
sentences = sentences[:-1]

for sentence in sentences : #sentence.split() :
    sentence2= TrimWordsSentence(normalizeString(sentence))
    #print(sentence2)
    output_words, attentions = evaluate(encoder1, attn_decoder1, sentence2)
    output_sentence = ' '.join(output_words)
    print(sentence)
    #print('=', sentence2)
    print('->', output_sentence)
    print('')
# Out:
# ['Bonjour', 'je suis intéressé par la data science', "C'est quand la rentrée", 'Quels sont les cours enseignés', 'Quelle est la durée du stage', 'On peut faire un stage recherche en laboratoire', 'Merci monsieur']
# Bonjour
# -> je suis a votre ecoute <EOS>
#
# je suis intéressé par la data science
# -> que faites-vous sur ce forum ? <EOS>
#
# C'est quand la rentrée
# -> le 5 septembre <EOS>
#
# Quels sont les cours enseignés
# -> il faut regarder sur notre site web <EOS>
#
# Quelle est la durée du stage
# -> le stage et 6 mois <EOS>
#
# On peut faire un stage recherche en laboratoire
# -> oui les a les tps de mars <EOS>
#
# Merci monsieur
# -> de rien <EOS>

# %% [markdown]
# Visualizing Attention
# ---------------------
#
# A useful property of the attention mechanism is its highly interpretable
# outputs. Because it is used to weight specific encoder outputs of the
# input sequence, we can imagine looking where the network is focused most
# at each time step.
#
# We simply run ``plt.matshow(attentions)`` to see attention output
# displayed as a matrix, with the columns being input steps and rows being
# output steps:

# %% [markdown]
# For a better viewing experience we will do the extra work of adding axes
# and labels:

# %%
def showAttention(input_sentence, output_words, attentions):
    # Set up figure with colorbar
    fig = plt.figure()
    ax = fig.add_subplot(111)
    cax = ax.matshow(attentions.numpy(), cmap='bone')
    fig.colorbar(cax)

    # Set up axes
    ax.set_xticklabels([''] + input_sentence.split(' ') +
                       ['<EOS>'], rotation=90)
    ax.set_yticklabels([''] + output_words)

    # Show label at every tick
    ax.xaxis.set_major_locator(ticker.MultipleLocator(1))
    ax.yaxis.set_major_locator(ticker.MultipleLocator(1))

    plt.show()

def evaluateAndShowAttention(input_sentence):
    output_words, attentions = evaluate(
        encoder1, attn_decoder1, input_sentence)
    showAttention(input_sentence, output_words, attentions)

evaluateAndShowAttention(TrimWordsSentence("quelle est la date de la rentree 2018 ?"))
evaluateAndShowAttention(TrimWordsSentence("il faut faire un stage en entreprise  ?"))

# %% [markdown]
# ---
# # TO DO
#
#
#
# -  Discuss the weaknesses of this simple approach
# -  Does the words'order really matter ? How could you check this ?
# -  Allow words in the new questions that were unseen during training.
# -  Allow questions of > 10 words (for instance, by selecting 10 words at random in the sentence).
# -  Adapt the code to handle several sequences at once (like an email)
# -  Replace the embeddings with pre-trained word embeddings such as word2vec (or GloVe).
# -  Try with more layers, more/less hidden units, and more sentences. Compare
#    the training time and performance.
# -  Define and plot other loss functions for this specific task (e.g. % correct words)

# %% [markdown]
# # Further ideas (optional)
# - Use "negative sampling", i.e. sampling random words to form incorrect questions (answering the question with something like 'I don't understand your question, sorry.' in order to enforce the model recognize a questions that are not syntactically (and semantically) correct.
# The probability for selecting a word as a negative sample should be related to its frequency, with more frequent words being more likely to be selected as negative samples.
# - To reduce the size of the input vocabulary and thus the computational burden, try to replace all the unknwon words with an unknown token <UNK> instead of ignoring them.
# -  Adapt the decoder to infer directly the word embeddings (semantic) in the output sentence.
